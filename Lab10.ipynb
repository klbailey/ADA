# %% [markdown]
# LAB 10
# Total points28/30
#
#
#  Concept Assessment: Choose the best answer.
#
# FIRST: Try to answer and browse the whole thing with stock knowledge and logical reasoning.
# THEN: Afterwards, you can go back to the questions you missed and check your notes or do a little research on it.
# Name:
# Kathy Bailey Hines
#
#
#
# In the field of statistics, what is the main purpose of descriptive statistics?
# 1/1
# a. Predicting future outcomes
# b. Drawing conclusions about a population based on a sample
# c. Summarizing and presenting data
# Correct
#
#
#
#
#
#
# Which numerical measures are commonly used for summarizing and understanding data in statistics?
# 1/1
# a. Probability distributions
# b. Mean, median, and standard deviation
# Correct
#
#
#
# c. Regression coefficients
#
#
#
# What distinguishes inferential statistics from descriptive statistics?
# 1/1
# a. Describing patterns and trends in data
# b. Making predictions about future events based on data
# Correct
#
#
#
# c. Summarizing data using measures like mean and median
#
#
#
# What is Gaussian Distribution?
# 1/1
# The distribution with a bell curve.
# Correct
#
#
#
# The distribution with rectangles.
# The distribution that swoops down.
#
#
#
# What is the primary purpose of descriptive statistics in the context of a dataset?
# 1/1
# a. Making predictions
# b. Summarizing and describing main features
# Correct
#
#
#
# c. Conducting hypothesis tests
#
#
#
# What is the primary goal of data collection in the field of statistics?
# 1/1
# a. Providing a historical record of events
# b. Generating random datasets for analysis
# c. Obtaining information to analyze, interpret, and draw conclusions
# Correct
#
#
#
#
#
#
# Which of the following is an example of descriptive statistics used to measure variability in a dataset?
# 1/1
# a. Hypothesis testing
# b. Mean
# c. Standard deviation
# Correct
#
#
#
#
#
#
# If you have the entire dataset for company sales and calculate the average (mean) of that dataset, it falls under the category of ___________.
# 1/1
# Descriptive Statistics
# Correct
#
#
#
# Inferential Statistics
# All of the above.
#
#
#
# What is random sampling?
# 1/1
# a. Selecting every nth item in the population
# b. Choosing a sample in a way that every individual has an equal chance of being selected
# Correct
#
#
#
# c. Picking samples based on personal preference
#
#
#
# Why is random sampling important?
# 1/1
# a. It guarantees a representative sample
# Correct
#
#
#
# b. It simplifies data collection
# c. It ensures a biased sample
#
#
#
# What is a common feature of proper data collection techniques?
# 1/1
# a. Limited sample diversity
# b. Consistent underreporting
# c. Adequate sample representation
# Correct
#
#
#
#
#
#
# What is the main purpose of probability in understanding events?
# 1/1
# a. Describing historical occurrences
# b. Predicting future outcomes
# Correct
#
#
#
# c. Summarizing numerical data
#
#
#
# Which term best describes the likelihood of raining tomorrow in the context of probability?
# 1/1
# a. Outcome
# b. Event
# c. Probability
# Correct
#
#
#
#
#
#
# If rolling an even number on a six-sided die is considered an event, what is the corresponding outcome?
# 1/1
# a. Rolling a 1 or 3
# b. Rolling a 2 or 4
# Correct
#
#
#
# c. Rolling a 5 or 6
#
#
#
# How do probability distributions assist in handling missing values?
# 1/1
# a. By discarding incomplete data
# b. By providing insights into the likelihood of various values and helping replace missing values
# Correct
#
#
#
# c. By ignoring missing values during analysis
#
#
#
# What is the term for the set of possible values from a random experiment?
# 0/1
# a. Event space
# Incorrect
#
#
#
# b. Probability distribution
# c. Random variable
# Correct answer
# c. Random variable
#
#
#
# In the example of rolling a six-sided die, what is the random variable?
# 1/1
# a. The die
# b. The number rolled
# Correct
#
#
#
# 1/6
#
#
#
# In the context of a random variable, what does the term "probability distribution" represent?
# 1/1
# a. The set of possible values
# b. The likelihood of each possible value occurring
# Correct
#
#
#
# c. The average of all possible values
#
#
#
# If a random variable has the potential to assume any real value/infinite number of values within a defined interval, what category of random variable does it belong to?
# 1/1
# a. Discrete random variable
# b. Continuous random variable
# Correct
#
#
#
# c. Deterministic variable
#
#
#
# If you toss a fair coin, and let Y represent the number of heads obtained, what type of random variable is Y?
# 1/1
# a. Discrete random variable
# Correct
#
#
#
# b. Continuous random variable
# c. Deterministic variable
#
#
#
# How does a continuous random variable differ from a discrete random variable?
# 1/1
# a. A continuous random variable can only take on integer values.
# b. A discrete random variable can take on any real value within a specified range.
# c. A continuous random variable can take on any real value within a specified range.
# Correct
#
#
#
#
#
#
# What is the primary purpose of using graphs in statistical analysis?
# 1/1
# a. Memorizing mathematical formulas
# b. Visualizing data and patterns
# Correct
#
#
#
# c. Generating random datasets
#
#
#
# Which type of graph is commonly used to represent the distribution of continuous data, such as the normal distribution?
# 1/1
# a. Pie chart
# b. Bar graph
# c. Histogram
# Correct
#
#
#
#
#
#
# In a normal distribution, where is the highest point on the curve, representing the most frequent values?
# 1/1
# a. Left tail
# b. Right tail
# c. Peak or center
# Correct
#
#
#
#
#
#
# How does a normal distribution curve change when the standard deviation increases?
# 1/1
# a. It becomes narrower
# b. It becomes wider
# Correct
#
#
#
# c. It remains unchanged
#
#
#
# Which of the following statements about normal distribution is correct?
# 1/1
# a. All normal distributions have the same mean.
# b. Normal distributions are always symmetrical.
# Correct
#
#
#
# c. Normal distributions cannot be represented graphically.
#
#
#
# What is the advantage of using a normal distribution curve in statistical analysis?
# 1/1
# a. It simplifies complex formulas.
# b. It provides a visual representation of data distribution.
# Correct
#
#
#
# c. It only applies to discrete datasets.
#
#
#
# A score of zero tells us that the value exactly matches the average, what would a score of +3 tell us?
#
# 0/1
# The value is much higher than the average.
# The value is much lower than the average.
# The value has a +3 standard deviation
# Incorrect
#
#
#
# Correct answer
# The value is much higher than the average.
#
#
#
# What is a key characteristic of Bayesian Statistics/Inference in terms of probability?
# 1/1
# a. It relies solely on repeated experiments
# b. It uses existing knowledge and updates it with new data
# Correct
#
#
#
# c. It focuses on counting the frequency of outcomes
#
#
#
# How does Frequentist Statistics determine probability?
# 1/1
# a. By updating existing knowledge with new data
# b. By describing the likelihood based on repeated experiments and counting outcomes
# Correct
#
#
#
# c. By considering previous knowledge related to the event
# This content is neither created nor endorsed by Google. Report Abuse - Terms of Service - Privacy Policy
# Google Forms
